# %% [markdown]
# # Bayesian Classifier
# In this lab, you will implement and assess the performance of the Bayesian Classifier.
#
# ## Lab Instructions:
# 1. Read the explanation above each requirement very well
# 2. Read the requirement very well before jumping into the code.
# 3. Some requirements have essay questions in them, make sure you do NOT miss them.
# 4. PLEASE Read the hints! They are clear and made to help you complete the requirement as fast as you should

# %%
#### always keep all your imports in the first cell ####
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import csv
import math

# %matplotlib inline

# %% [markdown]
# ## Requirement
#
# In this requirement, you will build the Bayesian Classifier and test its performance.
#
# You are provided with a data file **data1.csv** containing list of points and their corresponding classes. The format of the data files is shown in the table below.
#
# | |Class|Feature 1|Feature 1|
# |-|-|-|-|
# |Point#1|1|0.271633|-2.93224|
# |Point#2|1|7.020786|-1.98966|
# |Point#3|1|2.901827|-0.91291|
#
#
# You are also provided with a test data file **test_data.csv**. The file contains test points that are unlabelled (i.e. the class to which they belong is unknown).

# %%
# TODO [1] : Read the file 'data1.csv' into the variable data.
# data contains the training data together with labelled classes.
def read_data(file_name):
    # HINT 1: How is the data ordered in the file?
    # HINT 2: Do you need to cast the data you read from the file?
    data = np.asarray(pd.read_csv('data1.csv', sep=",", header=None))
    # print(data)
    return data


# read_data('data1.csv')

# %%
def read_test_data():

    # TODO [2.A]: Read the file 'test_data.csv' into the variable test_data
    # test_data contains the unlabelled test class.
    # HINT: Do you need to cast the data you read from the file?

    test_data = np.asarray(pd.read_csv('test_data.csv', sep=",", header=None))

    # TODO [2.B]: Read the file 'test_data_true.csv' into the variable test_data_true
    # test_data_true contains the actual classes of the test instances, which you will compare
    # against your predicted classes.
    # HINT: Do you need to cast the data you read from the file?

    test_data_true = np.asarray(pd.read_csv(
        'test_data_true.csv', sep=",", header=None))
    return test_data, test_data_true

# read_test_data()

# %% [markdown]
# ### Machine Learning Terminlology
# Machine learning problems use common termonology (names and notiations) to refer to certain things. It is useful to use this termonology throughout your code to make it readable.
#
# | | |
# |:-|:--- |
# |$M$:|A scalar; represents the number of training points in the training set.|
# |$K$:|A scalar; represents the number of test points in the test set.|
# |$N$:|A scalar; represents the number of features of training set/test set (dimensionality of data).|
# |$X$:|A numpy array of shape $(M \times N)$ containing the training data **without** its labels, where $M$ is the number of training points and $N$ is the number of features in the dataset (or dimensionality of features). <br/> Each element in $X$ is a tuple $(X_1, X_2, \dots, X_N)$ where $N$ is the number of features in the dataset.|
# |$X_{test}$:| A numpy array of shape $(K \times N)$ containing the test data, where $K$ is the number of test points and $N$ is the number of features in the dataset (or dimensionality of features). <br/> Each element in $X_{test}$ is a tuple $(X_1, X_2, \dots, X_N)$ where $N$ is the number of features in the dataset. <br/> The number of columns in $X_{test}$ is equal to the number of columns in $X$ (because they have the same number of features). However, the number of rows in $X_{test}$ is different to the number of rows in $X$.|
# |**$Y$:| A numpy array of shape $(M \times 1)$ containing the labels of the training data. Each row in $Y$ corresponds to the label of the training point in $X$.<br/> For example, $Y[j]$ corresponds to the label of the training point $X[j]$ where $0<=j<M$.|

# %%
# TODO [3]: Fill the values of M, K, N, X, XTest, and Y respectively.
# Do not fill them manually (i.e. do not set N = 3). They should be generic for any input file.
training_data = read_data('data1.csv')
test_data, test_data_true = read_test_data()

numClasses = 3
M = training_data.shape[0]
N = training_data.shape[1] - 1
K = test_data.shape[0]

X = training_data[:, 1:]
X_Test = test_data
Y = training_data[:, 0]

# %%
# TODO [4]: Draw a scatter plot for traning data, where each class is coloured by the colour corresponding
#           to its index in the colors array.
# Class 1 should be coloured in red, Class 2 should be coloured in green, and Class 3 should be coloured in blue.
# Hint: We have done a similar plot in the previous lab. What operation do we need to select training data
#       belonging to a certain class?

colors = ['r', 'g', 'b', 'c', 'y']

# This is X given that its the first class (X|C1)
X_C1 = training_data[Y == 1][:, 1:]
# This is X given that its the second class (X|C2)
X_C2 = training_data[Y == 2][:, 1:]
# This is X given that its the third class (X|C3)
X_C3 = training_data[Y == 3][:, 1:]


plt.scatter(X_C1[:, 0], X_C1[:, 1], color=colors[0])
plt.scatter(X_C2[:, 0], X_C2[:, 1], color=colors[1])
plt.scatter(X_C3[:, 0], X_C3[:, 1], color=colors[2])

plt.title('Training Data')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
## What do you notice about the plot? (Write everything you can think of)
'''
    Your Answer:

    - The dataset consists of three main clusters each corresponding to data belong to one class.

    - The overlap between the green cluster and the other two clusters is minimal compared to the overlap between the blue and red clusters.

    - We can easily calculate the decision boundary between any two classes

    - The red cluster exhibits the highest variance among the three, followed by the blue. The feature causing most of the variance in them is Feature 1.

    - The blue cluster doesn't seem to be as dense as the other two clusters.

'''
# Out:
# "\n    Your Answer:\n\n    - The dataset consists of three main clusters each corresponding to data belong to one class.\n\n    - The overlap between the green cluster and the other two clusters is minimal compared to the overlap between the blue and red clusters.\n\n    - We can easily calculate the decision boundary between any two classes\n\n    - The red cluster exhibits the highest variance among the three, followed by the blue. The feature causing most of the variance in them is Feature 1.\n\n    - The blue cluster doesn't seem to be as dense as the other two clusters.\n\n"

# %% [markdown]
# ### Bayesian Classifier
# The Bayesian Classifier calculates the probability of the test point belonging to each class, then the class with highest probability is assigned to the test point.
#
# Classification of $x_{test}$ = $argmax_{i} P\big(C_i|x_{test}\big)$ = $argmax_{i} P(x|C_i) * P(C_i)$
#
# * $P(C_i|x_{test})$: Posterior probability
# * $P(x|C_i)$: Class-conditional probability (or distribution)
# * $P(C_i)$: Class apriori probability
#
# **Note that** $P(C_i|x_{test}) \neq P(x_{test}|C_i) * P(C_i)$. Instead,  $P(C_i|x_{test}) = \frac{P(x_{test}|C_i) * P(C_i)}{P(x_{test})}$. However, when we compare multiple classes, the denominator $P(x_{test})$ is independent of the class $i$ and can be regarded as normalizing factor.
#
# **We start by** computing statistical parameters about each class from the data.
#
# For each class, we are interested in **three** parameters that will be used for calculating the Gaussian class-conditional distribution and the posterior probability.
#
# These parameters are:
#
# |||
# |:-|:-|
# |**Class Apriori Probability: ($P_C$)**| A scalar; the probability of class occurence (how frequent this class appears in the training data)|
# |**Class Mean: ($\mu$)**| A vector of shape $(N \times 1)$, it is the expected value (mean) calculated from the training points of each class.|
# |**Class Covariance Matrix: ($\Sigma$)**| A square symmetric matrix of shape $(N \times N)$ representing the covariances between all the feature calculated from the training points of the class. <br/> For example: Matrix element $\sigma^2_{12}$ is the covariance between the 1st and the 2nd features|

# %%
# A list of size (numClasses, 1) containing the a priori probabilities of each class in the training set.
pClasses = []

# A numpy array of size (numClasses, N) containing the mean points of each class in the training set.
estimate_means = []
# HINT: USE NP.MEAN

# A numpy array of size (numClasses, N, N) containing the covariance matrices of each class in the training set.
estimate_covariances = []
# HINT: USE NP.COV (Pay attenention for what it takes as an argument)
X_Classes = [X_C1, X_C2, X_C3]
for classIndex in range(numClasses):
    # TODO [5]: Estimate the parameters of the Gaussian distributions of the given classes.
    # Fill pClasses, estimate_means, and estimate_covariances in this part
    # Your code should be vectorized WITHOUT USING A SINGLE FOR LOOP.

    pClasses.append(round(np.sum(Y == (classIndex + 1))/len(Y),6))
    X_Class = X_Classes[classIndex]
    # For each class we need the mean w.r.t each of the two features
    estimate_means.append([np.mean(X_Class[:, 0]), np.mean(X_Class[:, 1])])
    estimate_covariances.append(np.cov(X_Class.T))

estimate_means = np.array(estimate_means)
estimate_covariances = np.array(estimate_covariances)

# %%
### Test your implementation ###
### DO NOT CHANGE THIS CODE ###
assert len(pClasses) == numClasses,\
        'Incorrect class apriori probability list, it should be of length {}'.format(len(pClasses))
assert np.sum(pClasses)==1,\
        'Sum of apriori probabilities should be 1, found {}'.format(np.sum(pClasses))

assert estimate_means.shape == (numClasses, N),\
        'Incorrect estimated means, it should be of shape {}'.format((numClasses, N))
assert estimate_covariances.shape == (numClasses, N, N),\
        'Incorrect estimate covariance matrices, it should be of shape {}'.format((numClasses, N, N))

# %% [markdown]
# **The second step** in the classifier is to calculate the class-conditional density using the Gaussian destribution:
#
# $P(x|C_i) = \mathcal{N}(x; \mu_i, \Sigma_i) = \frac{1}{(2\pi)^{\frac{N}{2}}|\Sigma_i|^{\frac{1}{2}}} exp\big(\frac{-1}{2}(x-\mu_i)^T\Sigma^{-1}_{i}(x-\mu_i)\big)$

# %%
# TODO 6: Implement the multivariate normal gaussian distribution with parameters mu and sigma, and return the
#  value in prob.
def multivariate_normal_gaussian(X, mu, sigma):
    scale = (2 * np.pi)**(len(mu)/2) * np.linalg.det(sigma)**(0.5)
    prob = np.exp(-0.5 * ( (X - mu).T @ np.linalg.inv(sigma) @  (X - mu))) / scale
    return prob

# %%
### Test your implementation ###
### DO NOT CHANGE THIS CODE ###
np.random.seed(90)
assertion_x = np.random.rand(3).reshape(-1,1)
assertion_mu = np.random.rand(3).reshape(-1,1)
assertion_sigma = np.random.rand(9).reshape(3,3)
assertion_probability = multivariate_normal_gaussian(assertion_x, assertion_mu, assertion_sigma)[0][0]
assertion_probability = round(assertion_probability, 1)

assert assertion_probability == 7.8,\
    'Incorrect Gaussian Probability calculated'

# %%
def Bayes(X, C, pClasses, estimate_means, estimate_covariances, N):    # computes P(X|C)*P(C)
    classConditional = multivariate_normal_gaussian(
        X, estimate_means[C], estimate_covariances[C])
    proir = pClasses[C]
    posterior_est = classConditional * proir
    return posterior_est

# %% [markdown]
# **The final step** is to go for each test point, calculate its posterior probability against each class, then classify it to the class with the highest posterior probability.

# %%
# TODO [7]: Apply the Bayesian Classifier to predict the classes of the test points.
# predicted_classes: A numpy array of size (K, 1) where K is the number of points in the test set. Every element in this array
predicted_classes = []
# contains the predicted class of Bayes classifier for this test point.

for i in range(X_Test.shape[0]):
    print("For test point:", X_Test[i])
    classProbabilities = np.zeros(numClasses)
    # TODO [7.A]: Compute the probability that the test point X_Test[i] belongs to each class in numClasses.
    #  Fill the array classProbabilities accordingly.
    classProbabilities[0] = Bayes(
        X_Test[i], 0, pClasses, estimate_means, estimate_covariances, N)
    classProbabilities[1] = Bayes(
        X_Test[i], 1, pClasses, estimate_means, estimate_covariances, N)
    classProbabilities[2] = Bayes(
        X_Test[i], 2, pClasses, estimate_means, estimate_covariances, N)

    # TODO [7.B]: Find the prediction of the test point X_Test[i] and append it to the predicted_classes array.
    predicted_classes.append(np.argmax(classProbabilities) + 1)

    # the first class is the left most in the scatter plot
    print('Class Probabilities: ', classProbabilities)
    print("Predicted class is :", predicted_classes[i])
    print("******************************************************************************")
# Out:
# For test point: [10.70141426  3.87253627]
# Class Probabilities:  [2.65667617e-12 2.14599760e-17 2.49128185e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.81831787 -5.00977814]
# Class Probabilities:  [1.54057746e-02 1.59733797e-10 1.94606724e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.57071936  9.96036181]
# Class Probabilities:  [7.93462973e-20 1.36556743e-03 5.38716919e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 4.94309043 -0.01539406]
# Class Probabilities:  [1.95768925e-06 1.94246360e-08 5.69469636e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 4.26082551 -0.61349358]
# Class Probabilities:  [6.2406293e-06 4.9842336e-08 4.7278965e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.98901139 16.86268221]
# Class Probabilities:  [4.48753351e-36 3.09285742e-04 1.66265779e-17]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.2796485  -3.38655342]
# Class Probabilities:  [2.21653532e-03 1.16512356e-07 8.33832911e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 2.60503344 -0.24206319]
# Class Probabilities:  [8.51743851e-05 1.94834828e-06 2.24458010e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.84312621 12.42130394]
# Class Probabilities:  [7.22910245e-20 5.21791755e-03 1.70141989e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-6.52253054 10.13668928]
# Class Probabilities:  [3.13514218e-25 1.40321611e-06 7.46136128e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 5.59472055 -4.37938379]
# Class Probabilities:  [2.85106791e-09 3.52756633e-12 1.15602087e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.98596817 -0.73837508]
# Class Probabilities:  [7.99412659e-04 1.19354012e-06 4.43428340e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-2.23908496 13.21358765]
# Class Probabilities:  [7.41763084e-26 3.31840031e-03 3.77648447e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ -6.7789975 -11.0163502]
# Class Probabilities:  [1.08876675e-03 1.60723575e-20 2.07172631e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.59545273 -0.41955489]
# Class Probabilities:  [5.73709966e-04 1.06972352e-05 4.58273024e-04]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 8.36129364 -5.42102971]
# Class Probabilities:  [4.93590069e-15 1.81083152e-17 2.37753886e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.52848225 -7.42893531]
# Class Probabilities:  [1.95401822e-03 5.80993682e-12 1.27194477e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.56086046 -9.03278997]
# Class Probabilities:  [2.59963726e-03 2.66267089e-15 4.98119323e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.02188067 -0.93735269]
# Class Probabilities:  [6.30158684e-09 6.99962996e-12 5.27535116e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [9.1509862  1.43750612]
# Class Probabilities:  [9.02781071e-11 1.11683109e-14 2.17486915e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.71007022 10.6797775 ]
# Class Probabilities:  [6.14532305e-19 9.85768066e-03 2.90112118e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.76302456 -5.55297678]
# Class Probabilities:  [1.71587005e-02 6.63592274e-12 2.25174311e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.89883417 -5.39496672]
# Class Probabilities:  [1.65351293e-02 6.68116095e-12 1.99600036e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [8.03379007 2.71590677]
# Class Probabilities:  [3.25891121e-09 6.33380270e-12 2.25024056e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.89215726 -2.59460822]
# Class Probabilities:  [2.35266950e-03 1.54638533e-09 1.07116497e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.11834647  4.91066223]
# Class Probabilities:  [1.04649738e-10 8.44017240e-05 3.54716282e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 6.45717699 -2.43934454]
# Class Probabilities:  [5.07994484e-09 6.00780130e-12 3.64389538e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [1.56547098 4.9207542 ]
# Class Probabilities:  [2.07859577e-07 1.10058925e-03 8.50551051e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.26265631 6.5794146 ]
# Class Probabilities:  [2.26255748e-09 3.47120278e-03 1.01432045e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 2.70832433 -3.11174424]
# Class Probabilities:  [3.09054292e-05 2.15868817e-08 1.14306036e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ -9.10836917 -11.76552446]
# Class Probabilities:  [8.17206740e-04 1.11871742e-25 1.87039658e-16]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.81726658 -5.3687788 ]
# Class Probabilities:  [1.66047205e-02 8.62791761e-12 2.38356675e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.30975347  9.75343174]
# Class Probabilities:  [1.72678436e-15 1.45116216e-02 1.24168689e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-7.58893623 -3.93631034]
# Class Probabilities:  [6.68507657e-04 2.69709966e-14 1.66022888e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-11.3843618 -12.1472865]
# Class Probabilities:  [2.36182213e-04 1.81519595e-31 1.48001136e-19]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 6.15303864 -5.99521012]
# Class Probabilities:  [9.52219374e-12 2.65861558e-14 2.49472340e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [0.88072334 9.72115039]
# Class Probabilities:  [2.03278564e-14 8.73359495e-03 5.14054623e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.3263618 8.7977202]
# Class Probabilities:  [1.52282079e-12 5.76222976e-03 4.07909198e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.70501109 11.56174259]
# Class Probabilities:  [1.23831566e-25 1.45196206e-04 2.03066201e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.12643357 -4.83616859]
# Class Probabilities:  [1.28546453e-02 7.52713142e-10 7.01437085e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 4.05674244 12.57155861]
# Class Probabilities:  [1.42657978e-17 2.98293184e-05 1.47833530e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ -4.30106198 -10.6042502 ]
# Class Probabilities:  [1.96591133e-04 6.64738444e-17 5.74517490e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 5.11776496 -0.99143917]
# Class Probabilities:  [8.67065155e-07 3.31293208e-09 5.48755229e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 6.05493358 -5.87189841]
# Class Probabilities:  [1.91155468e-11 4.69464649e-14 2.87310810e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 3.74275953 -3.97527522]
# Class Probabilities:  [1.18595118e-06 7.60485886e-10 1.09158008e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.02170247 -5.57244813]
# Class Probabilities:  [1.60749400e-02 3.28317612e-11 8.50670805e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.27810154 -3.99998321]
# Class Probabilities:  [7.21775655e-03 4.33519919e-11 2.60632978e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.80988364 3.43699512]
# Class Probabilities:  [1.87857860e-07 4.98276830e-08 2.01392871e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [8.6311676  1.76165524]
# Class Probabilities:  [5.20542641e-10 1.83337185e-13 2.59042466e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.73761305 -6.16978647]
# Class Probabilities:  [1.72079165e-02 1.82566848e-12 1.32334916e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [13.28411495 -2.28452888]
# Class Probabilities:  [1.67178590e-21 2.46223852e-27 2.69611274e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.47775397 -0.10213091]
# Class Probabilities:  [4.27673228e-04 5.64424733e-06 9.64959703e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.42758688 -7.1513932 ]
# Class Probabilities:  [1.15591182e-02 3.93607858e-13 8.04614773e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-1.71805696 -8.49355483]
# Class Probabilities:  [1.41749400e-04 1.02901530e-12 9.19852297e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.07056432 13.27106731]
# Class Probabilities:  [3.48135939e-29 2.95452807e-04 1.19575459e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.82594718 -9.52426172]
# Class Probabilities:  [1.53492886e-04 1.97327318e-14 4.00060150e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [10.2893587   1.35319816]
# Class Probabilities:  [1.93246787e-12 2.76184750e-17 1.04650591e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.13419282  9.00152907]
# Class Probabilities:  [7.59348929e-15 1.28409753e-02 1.62680304e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.29226867  7.97517886]
# Class Probabilities:  [2.71580835e-12 1.17677574e-02 2.65046024e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 9.46997908 -1.99299457]
# Class Probabilities:  [2.39959229e-13 3.36845522e-17 1.38598932e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.05416915 -2.47425901]
# Class Probabilities:  [3.74947151e-03 4.68398742e-07 5.06444215e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 2.21553241 12.53863186]
# Class Probabilities:  [8.06490242e-19 1.08467967e-03 4.74821826e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 8.85953786 -0.76518719]
# Class Probabilities:  [2.06774107e-11 3.60108110e-15 2.78656374e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 4.11560394 -2.51521659]
# Class Probabilities:  [2.59078610e-06 4.17945955e-09 2.79470987e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.88633577 -7.73994173]
# Class Probabilities:  [1.32138597e-02 2.03335069e-15 2.33177628e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-1.79933965  5.31322455]
# Class Probabilities:  [2.53450372e-09 2.35586906e-03 1.13693281e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 1.34271378 16.23529621]
# Class Probabilities:  [1.01454516e-28 2.78267044e-04 9.88572906e-15]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 1.55913997 10.48707791]
# Class Probabilities:  [2.63166880e-15 4.43196537e-03 2.29496101e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.86122888  7.15903434]
# Class Probabilities:  [3.15434523e-12 5.64339992e-03 1.04219184e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.38794864  4.18558645]
# Class Probabilities:  [5.87506309e-09 1.73911044e-04 2.67346716e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-9.52727338 -7.21208436]
# Class Probabilities:  [1.37168830e-03 4.09520361e-21 7.19071069e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.98956144 -7.5666012 ]
# Class Probabilities:  [1.16718422e-02 3.77404663e-14 1.71546190e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.75405923 -5.30192282]
# Class Probabilities:  [6.95118635e-04 1.25640389e-17 3.55309854e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.94621632 -6.88516599]
# Class Probabilities:  [1.04371803e-02 2.04401986e-12 2.55801698e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.31994442 -2.63044722]
# Class Probabilities:  [1.69857157e-03 4.89632965e-10 4.53858335e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-9.36297948 -8.56822792]
# Class Probabilities:  [2.89375182e-03 2.92800293e-22 2.03700575e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.81585174 -3.0905699 ]
# Class Probabilities:  [6.88547332e-03 6.52626826e-09 6.39616169e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [11.48384894 -2.13782697]
# Class Probabilities:  [2.43490485e-17 3.87480731e-22 2.42544261e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [7.38337554 4.66707989]
# Class Probabilities:  [5.90912584e-09 3.86405314e-10 7.24793228e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.19811716 -3.20869437]
# Class Probabilities:  [8.33437867e-03 1.52642275e-08 1.71443979e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.73664819 -5.64026754]
# Class Probabilities:  [1.73201664e-02 5.85707654e-12 2.18926763e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.16135146 8.11909452]
# Class Probabilities:  [1.39449920e-10 3.09076119e-06 1.16946653e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.93192373 -7.90304636]
# Class Probabilities:  [9.30692824e-03 1.91571525e-14 1.24385185e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 8.44663034 -1.10812617]
# Class Probabilities:  [5.29369958e-11 1.53334752e-14 3.20144121e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-10.41266737  -6.02755366]
# Class Probabilities:  [1.04013200e-04 7.28480563e-22 1.99048637e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-10.55452885  -6.98597699]
# Class Probabilities:  [2.43229450e-04 3.53443293e-23 5.08979039e-15]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.16708742 -4.41114641]
# Class Probabilities:  [1.31152697e-03 1.73945659e-08 4.93437694e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [6.83499316 3.0513492 ]
# Class Probabilities:  [4.11741195e-08 1.05374201e-09 2.48195592e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.3218284   8.03062152]
# Class Probabilities:  [2.08715583e-12 1.19554088e-02 2.34515820e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.67262506 -3.63638033]
# Class Probabilities:  [9.59812302e-03 1.47628738e-08 3.15311570e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.23839346 15.50904654]
# Class Probabilities:  [6.66222240e-27 5.80140120e-04 7.70462681e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.85415463 -9.49083878]
# Class Probabilities:  [3.74127712e-06 1.39220841e-13 5.58978743e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.57934474 14.05416562]
# Class Probabilities:  [1.45103223e-25 4.14231228e-03 5.08443609e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.08121918 9.02118593]
# Class Probabilities:  [4.60310973e-13 7.31367198e-03 2.20073875e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.54545494 13.38470402]
# Class Probabilities:  [1.52996279e-28 6.66099686e-04 2.45388948e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 0.25685021 12.98458764]
# Class Probabilities:  [8.23192009e-22 5.87566601e-03 2.26792108e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 8.49117921 -2.09111202]
# Class Probabilities:  [8.81985928e-12 3.09761950e-15 2.31677523e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [9.6377611  2.59220877]
# Class Probabilities:  [4.14289550e-11 2.76738953e-15 1.09511776e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 7.99632131 -0.81831291]
# Class Probabilities:  [3.57531367e-10 1.63139349e-13 4.07559238e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.8066989  12.60496257]
# Class Probabilities:  [1.77028952e-18 4.04530375e-04 6.41030405e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.14054117 13.99755821]
# Class Probabilities:  [8.29454693e-25 4.00477964e-03 1.04918078e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.0622924  -4.14345298]
# Class Probabilities:  [1.18451244e-02 3.27311617e-09 1.26744386e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.73588097 -8.59503648]
# Class Probabilities:  [7.97953228e-03 3.68934395e-16 9.99968247e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.87691909 -8.51465367]
# Class Probabilities:  [5.59644214e-03 4.72736970e-15 5.97594321e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 8.30461631 -2.42881748]
# Class Probabilities:  [9.38364371e-12 4.27091772e-15 2.18519205e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.92551153  9.38904848]
# Class Probabilities:  [1.88206146e-16 8.79591479e-03 2.55603607e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-8.06681967 -9.76445434]
# Class Probabilities:  [4.58042908e-03 3.98146842e-21 9.32524152e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.24410989 -8.18831047]
# Class Probabilities:  [6.57602623e-03 1.25859876e-19 6.13089477e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.37602904 -5.99069434]
# Class Probabilities:  [1.70089756e-02 5.28923142e-13 4.59475521e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.22386765 -4.85135398]
# Class Probabilities:  [1.23773787e-06 3.90395271e-10 4.52107203e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.55406083 -2.89224039]
# Class Probabilities:  [2.63146668e-04 1.25919257e-07 5.91536762e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.69049165 13.4044702 ]
# Class Probabilities:  [2.95306843e-20 3.34545738e-04 8.41276140e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.53571156 10.66187251]
# Class Probabilities:  [5.60674899e-20 5.06738419e-03 8.10365315e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 3.96782552 -4.31305255]
# Class Probabilities:  [4.04247149e-07 2.56097045e-10 9.23283068e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.00081432  8.87275799]
# Class Probabilities:  [1.67515504e-15 7.88095329e-03 5.69501858e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-5.35696677 -3.77423836]
# Class Probabilities:  [5.68498084e-03 5.42957921e-11 2.53165184e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.48811048 -3.16156655]
# Class Probabilities:  [4.56384790e-11 4.08006718e-14 2.02979150e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ -6.06573364 -13.36721214]
# Class Probabilities:  [7.53963167e-06 1.26531020e-22 7.00863301e-15]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.1851141 2.6171304]
# Class Probabilities:  [8.14106165e-07 1.67541150e-07 2.98411159e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [8.27828524 1.31354615]
# Class Probabilities:  [1.10560212e-09 5.83850680e-13 3.39686221e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [3.79242965 1.64031539]
# Class Probabilities:  [9.26494729e-06 2.10737173e-06 2.98023666e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.138666   6.8602675]
# Class Probabilities:  [1.89448617e-10 8.12960384e-03 1.59428237e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 5.78244942 -9.12198008]
# Class Probabilities:  [2.29089095e-15 6.96110318e-17 3.52906206e-06]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 3.60435329 -5.38072375]
# Class Probabilities:  [1.82459471e-07 6.81871198e-11 3.28809090e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.85525938 -6.34543458]
# Class Probabilities:  [1.27879593e-02 8.38326782e-12 5.37570884e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [13.08621387  1.9348786 ]
# Class Probabilities:  [6.86377065e-17 1.31615876e-24 5.32648097e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.97701781 -8.26247269]
# Class Probabilities:  [3.61946704e-03 6.90964259e-14 4.26738283e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [0.3366769  1.22185752]
# Class Probabilities:  [1.29748438e-04 9.39161175e-05 2.76505859e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-9.28532526 -9.4355402 ]
# Class Probabilities:  [3.06956105e-03 4.14727301e-23 7.04756959e-15]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.66429005 11.01189494]
# Class Probabilities:  [3.26438032e-16 3.60441464e-03 8.69321852e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.08966182 -1.69228564]
# Class Probabilities:  [2.45837326e-03 2.38064791e-07 3.38446259e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 6.33789356 -2.66619436]
# Class Probabilities:  [5.23542178e-09 6.31071407e-12 3.32397709e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.56901228  5.51033591]
# Class Probabilities:  [7.94608351e-09 4.31603105e-03 4.89058673e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 2.99286099 -4.68078563]
# Class Probabilities:  [2.84041877e-06 8.01002675e-10 4.67327507e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.80021733 11.42437424]
# Class Probabilities:  [9.51191345e-21 8.27062895e-03 5.18952884e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 1.16929961 -4.74585978]
# Class Probabilities:  [1.26842301e-04 5.78918227e-09 1.34516758e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.15245262 14.77479741]
# Class Probabilities:  [1.99538781e-26 2.19621636e-03 1.82856734e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-11.57247905  -6.73922446]
# Class Probabilities:  [2.60970748e-05 1.96025471e-25 3.08351534e-16]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.60476346  4.55773513]
# Class Probabilities:  [9.05062707e-12 2.08984100e-06 2.51845845e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 7.91493717 -4.93203896]
# Class Probabilities:  [1.37003338e-13 3.13128736e-16 4.64152662e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.40280867 -4.97280708]
# Class Probabilities:  [1.25337235e-02 4.37925682e-12 1.04766075e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [2.04297042 2.03014309]
# Class Probabilities:  [2.90521184e-05 5.95100414e-05 9.35059398e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ -6.21122011 -10.70086807]
# Class Probabilities:  [1.16055123e-03 2.72947238e-19 1.24362708e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.53064612 -8.83892725]
# Class Probabilities:  [6.04943894e-03 3.55431012e-16 1.05893648e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.30022088 11.20197432]
# Class Probabilities:  [1.75823349e-15 2.58282288e-04 2.02894504e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 0.52678262 11.00539841]
# Class Probabilities:  [3.54010268e-17 9.64922101e-03 2.79120289e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [6.2375991  2.80421505]
# Class Probabilities:  [1.36281145e-07 7.24159396e-09 2.95257432e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-7.1883182  -1.89030168]
# Class Probabilities:  [4.09664562e-05 5.03398045e-12 9.19626779e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.60122702 15.01466265]
# Class Probabilities:  [3.54713224e-28 2.21259902e-03 3.51254344e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.34641109 -4.86072033]
# Class Probabilities:  [3.91750555e-03 4.94832855e-09 8.83708543e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 6.63822042 -5.45296469]
# Class Probabilities:  [6.03133581e-12 1.54169643e-14 4.10064980e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [6.54807184 1.19913258]
# Class Probabilities:  [8.61501924e-08 5.25993177e-10 5.31204360e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [11.7595198   0.33353443]
# Class Probabilities:  [1.49437560e-15 1.69358696e-21 3.11246379e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [10.04384705  3.3153199 ]
# Class Probabilities:  [1.63552539e-11 5.69709153e-16 5.78023086e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [3.72322077 2.89573292]
# Class Probabilities:  [3.51938136e-06 8.15314279e-06 1.63550189e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.23412033 10.5086633 ]
# Class Probabilities:  [3.82776485e-22 4.26857416e-04 5.07664616e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [2.75812898 9.80988701]
# Class Probabilities:  [2.10400616e-13 8.77542234e-04 2.21523491e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [5.71709878 0.05250004]
# Class Probabilities:  [3.88528668e-07 2.23256586e-09 6.23702934e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.4383003  14.46253234]
# Class Probabilities:  [1.94242754e-33 8.08690424e-05 2.36866914e-16]
# Predicted class is : 2
# ******************************************************************************
# For test point: [10.31980548  5.65793048]
# Class Probabilities:  [6.53273747e-12 4.73874813e-16 7.50447354e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-10.37524372  -7.74958537]
# Class Probabilities:  [6.15614208e-04 1.39963518e-23 3.55298617e-15]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.60020077 -5.42453553]
# Class Probabilities:  [1.69751512e-02 1.28312510e-11 3.41456375e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.20850522 -0.73094364]
# Class Probabilities:  [3.77193950e-05 3.74177671e-07 3.07100297e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.67511969 -0.45766944]
# Class Probabilities:  [5.99089754e-11 1.26600683e-14 3.18618016e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.84241029 -2.07200837]
# Class Probabilities:  [3.83779615e-03 1.82737645e-07 4.60606422e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.02815393 0.12504483]
# Class Probabilities:  [1.71035277e-06 1.83493577e-08 5.75556564e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.63527967 10.82193815]
# Class Probabilities:  [7.11998778e-16 3.86455101e-03 1.25293256e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [4.69546404 1.63793279]
# Class Probabilities:  [2.72878921e-06 2.48567477e-07 4.03484471e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.20495861 -8.54182529]
# Class Probabilities:  [3.29787449e-03 2.11363779e-14 1.93917314e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.85664823  8.27107861]
# Class Probabilities:  [1.78032099e-19 7.44871587e-06 1.07085806e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-5.43266395 -7.3131535 ]
# Class Probabilities:  [1.46026021e-02 2.13704307e-14 9.88710620e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.43743782 10.57358038]
# Class Probabilities:  [2.47271147e-14 2.22922144e-04 7.92811509e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [4.51691079 1.90895905]
# Class Probabilities:  [3.12738342e-06 5.16556196e-07 3.49280159e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.95393725 -2.06290005]
# Class Probabilities:  [3.88441641e-05 8.16946961e-08 2.03950701e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.17022706 -4.71914956]
# Class Probabilities:  [8.04242123e-03 3.29674441e-09 3.24851993e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [6.87943361 0.56763302]
# Class Probabilities:  [3.09445559e-08 7.83639455e-11 5.67103334e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.90155375 -2.49446135]
# Class Probabilities:  [8.28534540e-13 2.52940635e-16 1.57149683e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.75309704 10.13350214]
# Class Probabilities:  [2.82204298e-15 9.38313168e-03 2.06153375e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-6.83046209 -9.95463151]
# Class Probabilities:  [3.68858475e-03 2.76801457e-19 1.20296544e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [7.48084666 2.21690041]
# Class Probabilities:  [1.17515347e-08 4.16253800e-11 3.30255763e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.51484158 16.05856446]
# Class Probabilities:  [1.47744861e-36 1.26592138e-04 1.38471977e-17]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.29796106 -1.51960377]
# Class Probabilities:  [2.55799330e-03 8.59738045e-07 1.19502122e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.04675075 14.39325425]
# Class Probabilities:  [2.80627600e-24 1.57901149e-03 1.44686346e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.33223697 -7.63241344]
# Class Probabilities:  [3.74325324e-03 1.08369936e-12 2.87593770e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.38944943 -9.23325113]
# Class Probabilities:  [1.74350404e-03 2.33165392e-15 4.97073673e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.74176393 -5.02512921]
# Class Probabilities:  [1.54083149e-02 2.13030209e-11 3.64044035e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-7.41004634 -5.5997003 ]
# Class Probabilities:  [4.72480385e-03 1.67497208e-15 7.84333673e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.09797276 -7.51282903]
# Class Probabilities:  [6.66457397e-03 1.26877902e-18 2.06837151e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.65055    14.73266536]
# Class Probabilities:  [2.10233475e-24 6.65526684e-04 1.04925840e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.15219027 3.63873026]
# Class Probabilities:  [2.77343381e-06 6.36132970e-04 1.75333983e-04]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.25543293  9.24132191]
# Class Probabilities:  [1.98383558e-15 1.25902222e-02 8.98401306e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.3701864  10.61688349]
# Class Probabilities:  [1.19045328e-19 5.98517115e-03 1.16796790e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-11.26329666  -7.92344489]
# Class Probabilities:  [1.70947715e-04 6.35564909e-26 2.08120464e-16]
# Predicted class is : 1
# ******************************************************************************
# For test point: [1.37598504 5.76529642]
# Class Probabilities:  [2.37662957e-08 2.14944691e-03 2.98256728e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.88140712 -3.02402962]
# Class Probabilities:  [6.40177929e-03 6.49485840e-09 5.87201522e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.66886091 -1.94857083]
# Class Probabilities:  [2.50112307e-03 6.09575610e-08 1.21408766e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.21817753 10.22511294]
# Class Probabilities:  [6.50255723e-16 1.24195613e-02 9.52156489e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 3.01734447 -3.01633766]
# Class Probabilities:  [1.80200905e-05 1.55727661e-08 1.41455960e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [2.45242039 2.18725534]
# Class Probabilities:  [1.94002704e-05 4.03147607e-05 1.16243710e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.81338366 -3.04810313]
# Class Probabilities:  [2.64601112e-05 2.04907734e-08 1.25131235e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.35226244  7.94145336]
# Class Probabilities:  [4.08259677e-13 9.72111202e-03 6.86843649e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.32479122 -9.12757714]
# Class Probabilities:  [1.35614667e-04 1.08953407e-13 1.55592513e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [10.99032273 -0.46466519]
# Class Probabilities:  [9.09213647e-15 6.89958277e-20 6.28471452e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-7.52557256 -5.00051738]
# Class Probabilities:  [2.51159471e-03 3.92117918e-15 9.65817373e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.31739532 -7.08917772]
# Class Probabilities:  [1.54196934e-02 5.00113287e-14 1.61626097e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-2.87484239  6.36256125]
# Class Probabilities:  [7.72654486e-12 1.46454133e-03 6.08402287e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.70055404 17.81508726]
# Class Probabilities:  [1.34099661e-38 1.38097787e-04 1.16559218e-18]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.83913631 -3.92362328]
# Class Probabilities:  [1.14205247e-02 1.32990234e-09 3.98931326e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.31785661 -8.22012729]
# Class Probabilities:  [8.87304618e-03 3.14756168e-15 3.87796410e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 4.41220473 -0.78866093]
# Class Probabilities:  [4.36735357e-06 2.74063480e-08 4.85835961e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 5.86521872 -3.83801546]
# Class Probabilities:  [3.29106590e-09 4.10160442e-12 1.72274903e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.27975169 -5.40685681]
# Class Probabilities:  [6.99380378e-03 7.16663500e-10 1.57890108e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [10.44252378  5.04836557]
# Class Probabilities:  [5.80296906e-12 1.81675110e-16 1.21972078e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.10454519 -8.59923558]
# Class Probabilities:  [5.95093131e-03 2.12255122e-15 3.44316892e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [0.79291315 9.94727029]
# Class Probabilities:  [6.73889132e-15 9.23207233e-03 3.07017885e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 6.54304649 -2.92516109]
# Class Probabilities:  [1.80482846e-09 2.05098717e-12 2.85022323e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.39028133 12.45758209]
# Class Probabilities:  [1.94378759e-20 6.86481235e-03 9.43472028e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [9.43284293 1.63188371]
# Class Probabilities:  [4.32924885e-11 3.32271784e-15 1.75666115e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [1.09569772 1.68119391]
# Class Probabilities:  [6.32640502e-05 1.04571522e-04 4.94483233e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 7.85994525 -1.67404675]
# Class Probabilities:  [1.68791052e-10 8.90474940e-14 3.49733972e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [10.72753408  1.0240291 ]
# Class Probabilities:  [2.67887693e-13 1.69757321e-18 7.80538712e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [2.36857973 2.77908536]
# Class Probabilities:  [9.80483893e-06 7.97356810e-05 8.12705890e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.46358952 -4.88042874]
# Class Probabilities:  [1.50199962e-14 3.23030298e-17 3.79291485e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-8.6591206 -3.386283 ]
# Class Probabilities:  [4.72956986e-05 9.52451081e-16 1.48232826e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [8.4916236  0.68401163]
# Class Probabilities:  [3.73622549e-10 1.14020304e-13 3.45332473e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-10.09417452 -10.83373126]
# Class Probabilities:  [1.16854482e-03 1.33621640e-26 7.57844188e-17]
# Predicted class is : 1
# ...
# For test point: [10.36682284 -2.94025912]
# Class Probabilities:  [5.66047192e-16 7.21097170e-20 4.52002502e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 9.17686513 -0.67617114]
# Class Probabilities:  [7.59216985e-12 8.79532063e-16 2.36765688e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.56032018 10.89248968]
# Class Probabilities:  [2.30863331e-15 1.06205241e-03 2.33157996e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [0.8138255 6.3426885]
# Class Probabilities:  [3.02666575e-09 4.43510784e-03 8.83212334e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.58026808  9.29140022]
# Class Probabilities:  [7.17638557e-16 1.08757529e-02 5.13391823e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 8.85860141 -1.00596681]
# Class Probabilities:  [1.44485296e-11 2.63239080e-15 2.66877542e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.81652326 -2.73427081]
# Class Probabilities:  [3.33901630e-05 3.45349126e-08 1.45745588e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.91081684 -2.76984203]
# Class Probabilities:  [3.71535395e-03 3.00696760e-07 5.38799593e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.06815545  9.53292586]
# Class Probabilities:  [1.40742870e-19 5.74701859e-04 4.77085495e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [7.34079799 3.06978894]
# Class Probabilities:  [1.48914612e-08 1.51934628e-10 2.26076830e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.64032058 12.0068455 ]
# Class Probabilities:  [6.50539268e-22 7.83804723e-03 1.78927146e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [11.02141864 -0.12519999]
# Class Probabilities:  [1.47626771e-14 8.67245066e-20 6.31473551e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [2.83660161 7.63741536]
# Class Probabilities:  [3.10701537e-10 6.27668857e-04 8.38596115e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 0.55253392 -2.86889414]
# Class Probabilities:  [1.00709589e-03 2.50464755e-07 2.52437615e-04]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.97166844 -3.22481456]
# Class Probabilities:  [1.73176189e-06 1.76718528e-09 1.88440015e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.98490968 -4.84749576]
# Class Probabilities:  [1.21777290e-02 9.10912832e-10 8.69878375e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [9.10588756 1.58507517]
# Class Probabilities:  [1.15411813e-10 1.61135004e-14 2.14732217e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 4.99945013 -3.95313184]
# Class Probabilities:  [3.91565262e-08 4.12299859e-11 1.51410348e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.71883232 15.1537229 ]
# Class Probabilities:  [2.21738712e-25 4.47917102e-04 3.44260874e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.33163346  9.72288532]
# Class Probabilities:  [1.88565271e-15 1.45484771e-02 1.27911529e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [11.04296746  1.25113376]
# Class Probabilities:  [1.08815722e-13 3.43146818e-19 5.70642567e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.22009129  9.65386874]
# Class Probabilities:  [3.24350111e-15 1.43269298e-02 1.67075815e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.70876068  2.17594789]
# Class Probabilities:  [1.21987004e-05 1.82075223e-04 1.53201221e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [4.51045177 7.56673947]
# Class Probabilities:  [5.92317305e-10 1.68156802e-05 2.16242834e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.29825485 13.66342044]
# Class Probabilities:  [1.36140402e-25 4.62363279e-03 5.15495069e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-9.72864588 -6.0121161 ]
# Class Probabilities:  [3.42109156e-04 2.57849034e-20 1.40733182e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.48899942 17.98748437]
# Class Probabilities:  [7.50745905e-37 1.40802646e-04 3.93903379e-18]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.77337683  7.24172304]
# Class Probabilities:  [1.82846959e-11 9.37784853e-03 4.27117219e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.05007773 15.12157932]
# Class Probabilities:  [7.26911695e-31 1.26493236e-03 2.96690263e-15]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.79351842 -4.31693215]
# Class Probabilities:  [1.33742297e-02 6.75971873e-10 3.36838577e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [7.23987052 0.84895898]
# Class Probabilities:  [1.42366649e-08 2.72509317e-11 5.11209737e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-7.30596448 -3.23156572]
# Class Probabilities:  [3.61196875e-04 3.02776644e-13 4.61774904e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.28227684 -5.29628215]
# Class Probabilities:  [1.48842294e-02 3.07362391e-12 1.02867514e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.84284999 -4.65776943]
# Class Probabilities:  [3.81581473e-13 7.05247072e-16 6.09100605e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.36231452 14.65339584]
# Class Probabilities:  [4.71392995e-30 1.35765403e-03 6.67705860e-15]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-5.11518005 -5.99608685]
# Class Probabilities:  [1.74825917e-02 1.04641817e-12 7.63345253e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [8.61237327 4.48009751]
# Class Probabilities:  [6.02795633e-10 1.64830605e-12 5.77005061e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.95457177 -2.6426557 ]
# Class Probabilities:  [6.53671214e-04 3.01023432e-07 4.02418282e-04]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.91149048 -9.43001297]
# Class Probabilities:  [4.24092318e-03 2.40800322e-17 1.99133089e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.90520993  5.66899844]
# Class Probabilities:  [3.90070641e-14 1.99334766e-06 3.91989222e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.82381941  9.48699204]
# Class Probabilities:  [1.24023377e-20 1.23586770e-04 1.14999482e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 3.51481518 -2.69629369]
# Class Probabilities:  [8.36885034e-06 1.08782975e-08 2.07377866e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 4.81850398 -1.42510573]
# Class Probabilities:  [1.27780436e-06 4.01669551e-09 4.78753306e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.32369809 -7.1393455 ]
# Class Probabilities:  [5.70650877e-03 3.55394197e-12 5.35917026e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.46861438 -1.4433357 ]
# Class Probabilities:  [2.41400492e-04 2.40818577e-09 4.40989255e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-1.98740359 -5.57716425]
# Class Probabilities:  [5.01197840e-03 6.79102038e-10 2.04410809e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [11.65009927  4.93480248]
# Class Probabilities:  [1.74050593e-13 1.32351155e-19 4.77389192e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.29799896 -4.9997967 ]
# Class Probabilities:  [1.32066098e-02 5.49526241e-12 1.26484424e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.39210413 -8.94948394]
# Class Probabilities:  [5.65184580e-03 9.13826273e-21 1.46620976e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.03147831 -1.78716335]
# Class Probabilities:  [1.56839160e-03 1.68620540e-06 2.18048679e-04]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.24658383 -0.90643208]
# Class Probabilities:  [3.34587332e-09 3.08894131e-12 5.04990523e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 3.56004924 -1.02757626]
# Class Probabilities:  [1.98925447e-05 1.27560653e-07 3.48766583e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 7.36264317 -0.22355351]
# Class Probabilities:  [4.76399900e-09 4.75501187e-12 5.27385197e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.87468243  1.68851414]
# Class Probabilities:  [3.05689404e-06 6.69081449e-06 5.86535851e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.71271544 -9.47990792]
# Class Probabilities:  [2.33190067e-05 8.15046193e-14 2.01538631e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-6.79673036 -6.33979581]
# Class Probabilities:  [1.11093571e-02 2.94808997e-15 1.61473393e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [0.06008745 9.97311029]
# Class Probabilities:  [1.43331808e-15 1.33325995e-02 1.28649682e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.82746067 -3.56345126]
# Class Probabilities:  [6.54187693e-03 3.12321757e-10 8.01635772e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-7.90632459 -9.21895769]
# Class Probabilities:  [6.21388377e-03 3.43114848e-20 3.23526531e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [7.36874346 0.62545597]
# Class Probabilities:  [8.95085575e-09 1.27728965e-11 5.11347700e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.22552188 -0.20662172]
# Class Probabilities:  [3.55277216e-10 1.32005850e-13 3.97356874e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.20850538 -2.82403166]
# Class Probabilities:  [4.45033525e-04 1.87472370e-07 4.62616413e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [3.21579751 2.94840046]
# Class Probabilities:  [4.92575345e-06 2.33290941e-05 1.23768320e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.20729307 -5.44771275]
# Class Probabilities:  [6.48177473e-03 7.12282486e-10 1.68874147e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.40036386 -5.32174925]
# Class Probabilities:  [1.44906362e-02 2.11649043e-12 7.96125238e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.15531485 -4.12155615]
# Class Probabilities:  [1.01785205e-03 2.94580810e-08 8.44373139e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [9.22382129 5.71360307]
# Class Probabilities:  [7.86497255e-11 1.59105007e-13 1.39962579e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.63952042 -4.65786291]
# Class Probabilities:  [2.03244486e-03 1.01082202e-08 2.43494202e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [9.15705042 1.29990602]
# Class Probabilities:  [7.95675644e-11 9.43749295e-15 2.23671725e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [10.95944226  1.34437573]
# Class Probabilities:  [1.67574619e-13 6.14107478e-19 6.03756789e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [12.70138697  4.8417071 ]
# Class Probabilities:  [5.15743301e-15 1.33332317e-22 1.68605120e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [8.13412403 8.8823782 ]
# Class Probabilities:  [4.67545664e-12 5.33499235e-11 3.31315790e-06]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.02416693 11.64233379]
# Class Probabilities:  [1.43515767e-21 6.75181292e-03 2.25681383e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.06908312 1.27293507]
# Class Probabilities:  [1.03682437e-04 6.78552444e-05 5.54510962e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 9.66236602 -2.51130178]
# Class Probabilities:  [3.55271861e-14 5.84999387e-18 9.69453405e-04]
# Predicted class is : 3
# ******************************************************************************

# %%
# TODO [8]: Compute the accuracy of the generated Bayesian classifier 
# WITHOUT USING ANY FOR LOOPs.
accuracy = np.sum(np.array(predicted_classes) == np.array(test_data_true).reshape(-1))/len(test_data_true)
print('Accuracy = ' + str(round(accuracy,4) * 100) + '%')
# Out:
# Accuracy = 95.56%

# %%
# TODO [9]: Generate a 3D-plot for the generated distributions. x-axis and y-axis represent the features of the data,
#           where z-axis represent the Gaussian probability N at this point.

x = np.linspace(-10, 10, 300)
y = np.linspace(-10, 15, 300)
X, Y = np.meshgrid(x, y)
Z = np.zeros(X.shape)
Z1 = np.zeros(X.shape)
Z2 = np.zeros(X.shape)
Z3 = np.zeros(X.shape)

for i in range(Z.shape[0]):
    for j in range(Z.shape[1]):
        # TODO [9]: Fill in the matrix Z which will represent the probability distribution of every point.
        # Z[i,j] represents the joint probability N(x,y) for x = i and y = j.
        # We want to draw the gaussian probability N(x,y) for all points.
        Z1[i, j] =  multivariate_normal_gaussian([X[i, j], Y[i, j]], estimate_means[0], estimate_covariances[0]) * pClasses[0]
        Z2[i, j] =  multivariate_normal_gaussian([X[i, j], Y[i, j]], estimate_means[1], estimate_covariances[1]) * pClasses[1]
        Z3[i, j] =  multivariate_normal_gaussian([X[i, j], Y[i, j]], estimate_means[2], estimate_covariances[2]) * pClasses[2]
        Z[i, j] = max(Z1[i,j], Z2[i,j], Z3[i,j])

# Make a 3D plot, do not change code
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis', linewidth=0)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
plt.show()
# Out:
# C:\Users\Zeyad Tarek\AppData\Local\Temp\ipykernel_21412\2093901419.py:24: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
# How can you judge your plot is correct?
'''
    Your Answer:
    By comparing to the dataset's scatterplot (at the specific class we're plotting for). 
    The Gaussian should be centered at the mean of the points and the way it's skewed/scaled depends on the covariance.
    If the data was spread in a certain direction, the covariance parameter will make the Gaussian skew/scale so that
    it spreads in a similar way.
'''
# Out:
# "\n    Your Answer:\n    By comparing to the dataset's scatterplot (at the specific class we're plotting for). \n    The Gaussian should be centered at the mean of the points and the way it's skewed/scaled depends on the covariance.\n    If the data was spread in a certain direction, the covariance parameter will make the Gaussian skew/scale so that\n    it spreads in a similar way.\n"
